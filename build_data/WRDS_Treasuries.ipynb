# %% [markdown]
# # WRDS CRSP Documentation
#
# ### Treasury Libraries
# `crsp_m_treasuries`
#
# Quote Data
# * tfz_dly: main file of treasury quotes
# * tfz_dly_ts2: supplemental series
# * tfz_dly_ft: matched to term structure at any given date
# * tfz_dly_cd: compilation of fed reported rates in tfz format
# * tfz_dly_cpi: compilation of cpi data
# * tfz_dly_rf2: compiled risk-free rate
#
# Identifying Info
# * tfz_iss: issue details (which are included automatically in queries.)
# * tfz_idx: description of KYTREASNOX codes

# %% [markdown]
# ### WRDS Python Manual
# https://wrds-www.wharton.upenn.edu/pages/support/programming-wrds/programming-python/querying-wrds-data-python/
#
# https://wrds-www.wharton.upenn.edu/pages/support/programming-wrds/programming-python/python-example-data-workflow/
#
# https://wrds-www.wharton.upenn.edu/pages/support/applications/python-replications/fama-french-factors-python/

# %% [markdown]
# ### CRSP Treasury Manual
#
# https://www.crsp.org/products/documentation/treasno-properties
#
# https://www.crsp.org/files/treasury_guide_0.pdf

# %%
import wrds
file_key = open("../../../keys/wrds_username.txt","r")
USERNAME = file_key.read()
file_key.close()

db = wrds.Connection(wrds_username=USERNAME)
#db.create_pgpass_file()
# Out:
# Loading library list...
# Done

# %%
import pandas as pd
import numpy as np
from datetime import date

# %% [markdown]
# # Library Info

# %%
libs = db.list_libraries()
libs_crsp = [item for item in libs if item.startswith('crsp')]
treasury_databases = db.list_tables('crsp_m_treasuries')
display(treasury_databases)
# Out:
# ['tfz_dly',
#  'tfz_dly_cd',
#  'tfz_dly_cpi',
#  'tfz_dly_ft',
#  'tfz_dly_rf2',
#  'tfz_dly_ts2',
#  'tfz_idx',
#  'tfz_iss',
#  'tfz_mast',
#  'tfz_mth',
#  'tfz_mth_bp',
#  'tfz_mth_cd',
#  'tfz_mth_cpi',
#  'tfz_mth_fb',
#  'tfz_mth_ft',
#  'tfz_mth_rf',
#  'tfz_mth_rf2',
#  'tfz_mth_ts',
#  'tfz_mth_ts2',
#  'tfz_pay']

# %%
db.describe_table(library='crsp_m_treasuries', table='tfz_dly')
# Out:
# Approximately 3275455 rows in crsp_m_treasuries.tfz_dly.
#               name  nullable              type comment
# 0        kytreasno      True  DOUBLE_PRECISION    None
# 1         kycrspid      True       VARCHAR(15)    None
# 2            caldt      True              DATE    None
# 3            tdbid      True  DOUBLE_PRECISION    None
# 4            tdask      True  DOUBLE_PRECISION    None
# 5         tdnomprc      True  DOUBLE_PRECISION    None
# 6     tdnomprc_flg      True        VARCHAR(1)    None
# 7         tdsourcr      True        VARCHAR(1)    None
# 8         tdaccint      True  DOUBLE_PRECISION    None
# 9         tdretnua      True  DOUBLE_PRECISION    None
# 10           tdyld      True  DOUBLE_PRECISION    None
# 11        tdduratn      True  DOUBLE_PRECISION    None
# 12        tdpubout      True  DOUBLE_PRECISION    None
# 13        tdtotout      True  DOUBLE_PRECISION    None
# 14         tdpdint      True  DOUBLE_PRECISION    None
# 15      tdidxratio      True  DOUBLE_PRECISION    None
# 16  tdidxratio_flg      True        VARCHAR(1)    None

# %% [markdown]
# # Database quote

# %%
DATE = '2022-12-30'
SQL_QUERY = f'select * from crsp_m_treasuries.tfz_dly where caldt=\'{DATE}\''
data_quotes = db.raw_sql(SQL_QUERY)
data_quotes
# Out:
#      kytreasno         kycrspid       caldt       tdbid       tdask  \
# 0     204099.0  20370215.104750  2022-12-30  109.468750  109.531250
# 1     204081.0  20230215.107120  2022-12-30  100.265625  100.296875
# 2     204088.0  20261115.106500  2022-12-30  108.328125  108.375000
# 3     204092.0  20280815.105500  2022-12-30  107.000000  107.046875
# 4     204093.0  20281115.105250  2022-12-30  106.046875  106.093750
# ..         ...              ...         ...         ...         ...
# 429   207967.0  20230511.400000  2022-12-30   98.326167   98.350000
# 430   207972.0  20251115.204500  2022-12-30  100.632812  100.664062
# 431   207973.0  20271130.203870  2022-12-30   99.441406   99.488281
# 432   207976.0  20421115.104000  2022-12-30   97.984375   98.046875
# 433   207977.0  20521115.104000  2022-12-30  100.562500  100.625000
#
#        tdnomprc tdnomprc_flg tdsourcr  tdaccint  tdretnua     tdyld  \
# 0    109.500000            M        I  1.768342 -0.005679  0.000105
# 1    100.281250            M        I  2.652514 -0.000571  0.000130
# 2    108.351562            M        I  0.808011 -0.002584  0.000112
# 3    107.023438            M        I  2.047554 -0.002079  0.000111
# 4    106.070312            M        I  0.652624 -0.001545  0.000110
# ..          ...          ...      ...       ...       ...       ...
# 429   98.338083            M        I  0.000000 -0.000379  0.000127
# 430  100.648438            M        I  0.559392 -0.001304  0.000115
# 431   99.464844            M        I  0.319368 -0.002627  0.000108
# 432   98.015625            M        I  0.497238 -0.009861  0.000112
# 433  100.593750            M        I  0.497238 -0.011202  0.000108
#
#         tdduratn  tdpubout  tdtotout  tdpdint  tdidxratio tdidxratio_flg
# 0    3824.361582    4976.0   16589.0      0.0         NaN           None
# 1      47.000000    4735.0   15782.0      0.0         NaN           None
# 2    1271.885983    4266.0   10860.0      0.0         NaN           None
# 3    1772.052591    4635.0   11776.0      0.0         NaN           None
# 4    1873.297061    7738.0   10947.0      0.0         NaN           None
# ..           ...       ...       ...      ...         ...            ...
# 429   132.000000       NaN   50415.0      0.0         NaN           None
# 430   992.593427   39999.0   54027.0      0.0         NaN           None
# 431  1646.987389   42995.0   47670.0      0.0         NaN           None
# 432  5024.980206   14987.0   16617.0      0.0         NaN           None
# 433  6443.887004   38975.0   46340.0      0.0         NaN           None
#
# [434 rows x 17 columns]

# %%
KEYS = tuple(data_quotes['kytreasno'])
SQL_QUERY = f'select * from crsp_m_treasuries.tfz_iss where kytreasno in {KEYS}'
data_iss = db.raw_sql(SQL_QUERY)
data_iss
# Out:
#      kytreasno         kycrspid           crspid    tcusip      tdatdt  \
# 0     204081.0  20230215.107120  20230215.107120  912810EP  1993-02-15
# 1     204082.0  20230815.106250  20230815.106250  912810EQ  1993-08-16
# 2     204083.0  20241115.107500  20241115.107500  912810ES  1994-05-15
# 3     204084.0  20250215.107620  20250215.107620  912810ET  1995-02-15
# 4     204085.0  20250815.106870  20250815.106870  912810EV  1995-08-15
# ..         ...              ...              ...       ...         ...
# 429   207986.0  20231228.400000  20231228.400000  912796ZN  2022-12-29
# 430   207987.0  20241231.204250  20241231.204250  91282CGD  2022-12-31
# 431   207988.0  20251215.204000  20251215.204000  91282CGA  2022-12-15
# 432   207989.0  20271231.203870  20271231.203870  91282CGC  2022-12-31
# 433   207990.0  20291231.203870  20291231.203870  91282CGB  2022-12-31
#
#          tmatdt  iwhy  tcouprt  tnippy    tvalfc  ... tfcaldt  tnotice iymcn  \
# 0    2023-02-15   0.0    7.125     2.0  3.562500  ...    None      0.0  None
# 1    2023-08-15   0.0    6.250     2.0  3.108016  ...    None      0.0  None
# 2    2024-11-15   0.0    7.500     2.0  3.750000  ...    None      0.0  None
# 3    2025-02-15   0.0    7.625     2.0  3.812500  ...    None      0.0  None
# 4    2025-08-15   0.0    6.875     2.0  3.437500  ...    None      0.0  None
# ..          ...   ...      ...     ...       ...  ...     ...      ...   ...
# 429  2023-12-28   0.0    0.000     0.0  0.000000  ...    None      0.0  None
# 430  2024-12-31   0.0    4.250     2.0  2.125000  ...    None      0.0  None
# 431  2025-12-15   0.0    4.000     2.0  2.000000  ...    None      0.0  None
# 432  2027-12-31   0.0    3.875     2.0  1.937500  ...    None      0.0  None
# 433  2029-12-31   0.0    3.875     2.0  1.937500  ...    None      0.0  None
#
#      itype iuniq  itax  iflwr  tbankdt  tstripelig tfrgntgt
# 0      1.0   0.0   1.0    1.0     None        None     None
# 1      1.0   0.0   1.0    1.0     None        None     None
# 2      1.0   0.0   1.0    1.0     None        None     None
# 3      1.0   0.0   1.0    1.0     None        None     None
# 4      1.0   0.0   1.0    1.0     None        None     None
# ..     ...   ...   ...    ...      ...         ...      ...
# 429    4.0   0.0   1.0    1.0     None        None     None
# 430    2.0   0.0   1.0    1.0     None        None     None
# 431    2.0   0.0   1.0    1.0     None        None     None
# 432    2.0   0.0   1.0    1.0     None        None     None
# 433    2.0   0.0   1.0    1.0     None        None     None
#
# [434 rows x 22 columns]

# %%
data = data_quotes.merge(data_iss, on='kytreasno')
data
# Out:
#      kytreasno       kycrspid_x       caldt       tdbid       tdask  \
# 0     204099.0  20370215.104750  2022-12-30  109.468750  109.531250
# 1     204081.0  20230215.107120  2022-12-30  100.265625  100.296875
# 2     204088.0  20261115.106500  2022-12-30  108.328125  108.375000
# 3     204092.0  20280815.105500  2022-12-30  107.000000  107.046875
# 4     204093.0  20281115.105250  2022-12-30  106.046875  106.093750
# ..         ...              ...         ...         ...         ...
# 429   207967.0  20230511.400000  2022-12-30   98.326167   98.350000
# 430   207972.0  20251115.204500  2022-12-30  100.632812  100.664062
# 431   207973.0  20271130.203870  2022-12-30   99.441406   99.488281
# 432   207976.0  20421115.104000  2022-12-30   97.984375   98.046875
# 433   207977.0  20521115.104000  2022-12-30  100.562500  100.625000
#
#        tdnomprc tdnomprc_flg tdsourcr  tdaccint  tdretnua  ...  tfcaldt  \
# 0    109.500000            M        I  1.768342 -0.005679  ...     None
# 1    100.281250            M        I  2.652514 -0.000571  ...     None
# 2    108.351562            M        I  0.808011 -0.002584  ...     None
# 3    107.023438            M        I  2.047554 -0.002079  ...     None
# 4    106.070312            M        I  0.652624 -0.001545  ...     None
# ..          ...          ...      ...       ...       ...  ...      ...
# 429   98.338083            M        I  0.000000 -0.000379  ...     None
# 430  100.648438            M        I  0.559392 -0.001304  ...     None
# 431   99.464844            M        I  0.319368 -0.002627  ...     None
# 432   98.015625            M        I  0.497238 -0.009861  ...     None
# 433  100.593750            M        I  0.497238 -0.011202  ...     None
#
#      tnotice  iymcn  itype  iuniq  itax iflwr tbankdt tstripelig tfrgntgt
# 0        0.0   None    1.0    0.0   1.0   1.0    None       None     None
# 1        0.0   None    1.0    0.0   1.0   1.0    None       None     None
# 2        0.0   None    1.0    0.0   1.0   1.0    None       None     None
# 3        0.0   None    1.0    0.0   1.0   1.0    None       None     None
# 4        0.0   None    1.0    0.0   1.0   1.0    None       None     None
# ..       ...    ...    ...    ...   ...   ...     ...        ...      ...
# 429      0.0   None    4.0    0.0   1.0   1.0    None       None     None
# 430      0.0   None    2.0    0.0   1.0   1.0    None       None     None
# 431      0.0   None    2.0    0.0   1.0   1.0    None       None     None
# 432      0.0   None    1.0    0.0   1.0   1.0    None       None     None
# 433      0.0   None    1.0    0.0   1.0   1.0    None       None     None
#
# [434 rows x 38 columns]

# %% [markdown]
# # Get Yield Curve Data (CRSP)

# %%
data_ft = db.get_table(library='crsp_m_treasuries', table='tfz_dly_ft').pivot_table(index='caldt',values='tdytm', columns='kytreasnox')
tag_yield_file = data_ft.index[-1].strftime('%Y-%m-%d')
data_ft.columns = [1,2,5,7,10,20,30]
data_ft
# Out:
#                   1         2         5         7         10        20  \
# caldt
# 1961-06-14  2.935907  3.360687  3.623677  3.768720  3.818819  3.814210
# 1961-06-15  2.932936  3.376460  3.671691  3.804225  3.862987  3.828220
# 1961-06-16  2.929949  3.375670  3.685431  3.804216  3.863282  3.832922
# 1961-06-19  2.920884  3.389970  3.712984  3.824557  3.886205  3.842378
# 1961-06-20  2.952419  3.355796  3.685391  3.809274  3.886506  3.856465
# ...              ...       ...       ...       ...       ...       ...
# 2022-11-23  4.666103  4.465921  3.886053  3.657613  3.665568  4.010443
# 2022-11-25  4.654875  4.442006  3.859520  3.629335  3.652183  3.995460
# 2022-11-28  4.635645  4.420958  3.868822  3.640823  3.650411  3.996127
# 2022-11-29  4.658083  4.462683  3.918990  3.696951  3.714694  4.065729
# 2022-11-30  4.684844  4.264782  3.752390  3.525869  3.572437  3.979912
#
#                   30
# caldt
# 1961-06-14  3.815172
# 1961-06-15  3.826316
# 1961-06-16  3.830049
# 1961-06-19  3.837543
# 1961-06-20  3.845018
# ...              ...
# 2022-11-23  3.723134
# 2022-11-25  3.735102
# 2022-11-28  3.720517
# 2022-11-29  3.799570
# 2022-11-30  3.735334
#
# [15346 rows x 7 columns]

# %% [markdown]
# # Get Timeseries for certain maturities

# %%
MATDT = '2020-08-15'

SQL_QUERY = f'select * from crsp_m_treasuries.tfz_iss where tmatdt=\'{MATDT}\''
ts_info = db.raw_sql(SQL_QUERY)
#temp = temp[temp['itype'].isin([11,12]) == DOTIPS]
ts_info = ts_info.iloc[[0,1],:]
ts_info
# Out:
#    kytreasno         kycrspid           crspid    tcusip      tdatdt  \
# 0   204074.0  20200815.108750  20200815.108750  912810EG  1990-08-15
# 1   206169.0  20200815.202620  20200815.202620  912828NT  2010-08-15
#
#        tmatdt  iwhy  tcouprt  tnippy  tvalfc  ... tfcaldt  tnotice iymcn  \
# 0  2020-08-15   1.0    8.750     2.0  4.3750  ...    None      0.0  None
# 1  2020-08-15   1.0    2.625     2.0  1.3125  ...    None      0.0  None
#
#    itype iuniq  itax  iflwr  tbankdt  tstripelig tfrgntgt
# 0    1.0   0.0   1.0    1.0     None        None     None
# 1    2.0   0.0   1.0    1.0     None        None     None
#
# [2 rows x 22 columns]

# %%
if ts_info.shape[0]>1:
    KEYNO = tuple(ts_info['kytreasno'])
    SQL_QUERY = f'select * from crsp_m_treasuries.tfz_dly where kytreasno in {KEYNO}'
else:
    KEYNO = ts_info['kytreasno'].values[0]
    SQL_QUERY = f'select * from crsp_m_treasuries.tfz_dly where kytreasno =\'{KEYNO}\''
    
ts = db.raw_sql(SQL_QUERY)
ts
# Out:
#        kytreasno         kycrspid       caldt       tdbid       tdask  \
# 0       204074.0  20200815.108750  1993-04-13  122.593750  122.656250
# 1       204074.0  20200815.108750  1990-08-10   99.562500   99.625000
# 2       204074.0  20200815.108750  1990-08-13   99.187500   99.250000
# 3       204074.0  20200815.108750  1990-08-14   99.656250   99.718750
# 4       204074.0  20200815.108750  1990-08-15   99.843750   99.906250
# ...          ...              ...         ...         ...         ...
# 10001   206169.0  20200815.202620  2017-07-07  103.039062  103.070312
# 10002   206169.0  20200815.202620  2017-07-10  103.039062  103.054688
# 10003   206169.0  20200815.202620  2017-07-11  103.093750  103.125000
# 10004   206169.0  20200815.202620  2017-07-12  103.203125  103.234375
# 10005   206169.0  20200815.202620  2017-07-13  103.148438  103.179688
#
#          tdnomprc tdnomprc_flg tdsourcr  tdaccint  tdretnua     tdyld  \
# 0      122.625000            M        R  1.377762  0.001204  0.000186
# 1       99.593750            M        R  0.000000       NaN  0.000235
# 2       99.218750            M        R  0.000000 -0.003765  0.000236
# 3       99.687500            M        R  0.000000  0.004724  0.000235
# 4       99.875000            M        R  0.000000  0.001881  0.000235
# ...           ...          ...      ...       ...       ...       ...
# 10001  103.054688            M        I  1.029696  0.000070  0.000044
# 10002  103.046875            M        I  1.051450  0.000134  0.000044
# 10003  103.109375            M        I  1.058702  0.000670  0.000043
# 10004  103.218750            M        I  1.065953  0.001120  0.000042
# 10005  103.164062            M        I  1.073204 -0.000455  0.000043
#
#           tdduratn  tdpubout  tdtotout  tdpdint tdidxratio tdidxratio_flg
# 0      4387.142817   21009.0   21419.0      0.0       None           None
# 1      4021.731911       NaN       NaN      0.0       None           None
# 2      4006.695342       NaN       NaN      0.0       None           None
# 3      4017.732737       NaN       NaN      0.0       None           None
# 4      4021.154173       NaN       NaN      0.0       None           None
# ...            ...       ...       ...      ...        ...            ...
# 10001  1087.375558   34231.0   67850.0      0.0       None           None
# 10002  1084.375623   34231.0   67850.0      0.0       None           None
# 10003  1083.396165   34231.0   67850.0      0.0       None           None
# 10004  1082.431479   34231.0   67850.0      0.0       None           None
# 10005  1081.415137   34231.0   67850.0      0.0       None           None
#
# [10006 rows x 17 columns]

# %% [markdown]
# # Get Timeseries for certain issues

# %%
KEYNO_ts = (207816,207818)

SQL_QUERY = f'select * from crsp_m_treasuries.tfz_dly where kytreasno in {KEYNO_ts}'

ts_issue = db.raw_sql(SQL_QUERY)
ts_issue
# Out:
#      kytreasno         kycrspid       caldt      tdbid      tdask   tdnomprc  \
# 0     207818.0  20221229.400000  2022-01-12  99.561250  99.571000  99.566125
# 1     207816.0  20220630.400000  2022-03-23  99.862500  99.865250  99.863875
# 2     207816.0  20220630.400000  2022-03-24  99.861167  99.863889  99.862528
# 3     207816.0  20220630.400000  2022-03-25  99.846417  99.859889  99.853153
# 4     207816.0  20220630.400000  2022-03-28  99.848556  99.853778  99.851167
# ..         ...              ...         ...        ...        ...        ...
# 211   207818.0  20221229.400000  2022-03-25  99.062250  99.070000  99.066125
# 212   207818.0  20221229.400000  2022-03-28  98.988000  99.041667  99.014833
# 213   207818.0  20221229.400000  2022-03-29  99.018403  99.083333  99.050868
# 214   207818.0  20221229.400000  2022-03-30  99.079056  99.086667  99.082861
# 215   207818.0  20221229.400000  2022-03-31  99.082417  99.090000  99.086208
#
#     tdnomprc_flg tdsourcr  tdaccint  tdretnua     tdyld  tdduratn tdpubout  \
# 0              M        I       0.0 -0.000110  0.000012     351.0     None
# 1              M        I       0.0  0.000097  0.000014      99.0     None
# 2              M        I       0.0 -0.000013  0.000014      98.0     None
# 3              M        I       0.0 -0.000094  0.000015      97.0     None
# 4              M        I       0.0 -0.000020  0.000016      94.0     None
# ..           ...      ...       ...       ...       ...       ...      ...
# 211            M        I       0.0 -0.001240  0.000034     279.0     None
# 212            M        I       0.0 -0.000518  0.000036     276.0     None
# 213            M        I       0.0  0.000364  0.000035     275.0     None
# 214            M        I       0.0  0.000323  0.000034     274.0     None
# 215            M        I       0.0  0.000034  0.000034     273.0     None
#
#      tdtotout  tdpdint tdidxratio tdidxratio_flg
# 0     38798.0      0.0       None           None
# 1     58198.0      0.0       None           None
# 2     58198.0      0.0       None           None
# 3     58198.0      0.0       None           None
# 4     58198.0      0.0       None           None
# ..        ...      ...        ...            ...
# 211   38798.0      0.0       None           None
# 212   38798.0      0.0       None           None
# 213   38798.0      0.0       None           None
# 214   38798.0      0.0       None           None
# 215   38798.0      0.0       None           None
#
# [216 rows x 17 columns]

# %% [markdown]
# # Get Timeseries for TIPS issues

# %%
KEYNO_tips = (207431,206999,207009)

SQL_QUERY = f'select * from crsp_m_treasuries.tfz_dly where kytreasno in {KEYNO_tips}'

ts_issue_tips = db.raw_sql(SQL_QUERY)
ts_issue_tips
# Out:
#       kytreasno         kycrspid       caldt       tdbid       tdask  \
# 0      207431.0  20241015.C00120  2019-10-10   99.765625   99.796875
# 1      206999.0  20260715.C00120  2016-12-23   95.968750   96.101562
# 2      206999.0  20260715.C00120  2016-12-27   95.917969   96.050781
# 3      206999.0  20260715.C00120  2016-12-28   96.121094   96.253906
# 4      206999.0  20260715.C00120  2016-12-29   96.214844   96.347656
# ...         ...              ...         ...         ...         ...
# 3580   207431.0  20241015.C00120  2022-05-24  102.863281  102.898438
# 3581   207431.0  20241015.C00120  2022-05-25  102.882812  102.917969
# 3582   207431.0  20241015.C00120  2022-05-26  103.136719  103.171875
# 3583   207431.0  20241015.C00120  2022-05-27  103.109375  103.144531
# 3584   207431.0  20241015.C00120  2022-05-31  102.972656  103.007812
#
#         tdnomprc tdnomprc_flg tdsourcr  tdaccint  tdretnua  tdyld  tdduratn  \
# 0      99.781250            M        I       0.0       NaN    NaN       NaN
# 1      96.035156            M        I       0.0       NaN    NaN       NaN
# 2      95.984375            M        I       0.0       NaN    NaN       NaN
# 3      96.187500            M        I       0.0       NaN    NaN       NaN
# 4      96.281250            M        I       0.0       NaN    NaN       NaN
# ...          ...          ...      ...       ...       ...    ...       ...
# 3580  102.880859            M        I       0.0       NaN    NaN       NaN
# 3581  102.900391            M        I       0.0       NaN    NaN       NaN
# 3582  103.154297            M        I       0.0       NaN    NaN       NaN
# 3583  103.126953            M        I       0.0       NaN    NaN       NaN
# 3584  102.990234            M        I       0.0       NaN    NaN       NaN
#
#       tdpubout  tdtotout  tdpdint  tdidxratio tdidxratio_flg
# 0          NaN       NaN      0.0     1.00001              C
# 1      23999.0   37103.0      0.0     1.00809              C
# 2      23999.0   37103.0      0.0     1.00826              C
# 3      23999.0   37103.0      0.0     1.00830              C
# 4      23999.0   37103.0      0.0     1.00834              C
# ...        ...       ...      ...         ...            ...
# 3580   31724.0   38889.0      0.0     1.11678              C
# 3581   31724.0   38889.0      0.0     1.11725              C
# 3582   31724.0   38889.0      0.0     1.11773              C
# 3583   31724.0   38889.0      0.0     1.11821              C
# 3584   31724.0   39415.0      0.0     1.12011              C
#
# [3585 rows x 17 columns]

# %% [markdown]
# # Get Timeseries for Duration Analysis

# %%
KEYNO_ts_duration = (207392, 207391, 207457)
SQL_QUERY = f'select * from crsp_m_treasuries.tfz_dly where kytreasno in {KEYNO_ts_duration}'
ts_issue_duration = db.raw_sql(SQL_QUERY)
ts_issue_duration

infoflds = ['tdatdt','tmatdt','tcouprt','itype']
labels = ['issue date','maturity date','coupon rate','security type']
rename_dict = {infoflds[i]:labels[i] for i in range(len(infoflds))}
info_ts_duration = data_iss.set_index('kytreasno').loc[list(KEYNO_ts_duration),infoflds].rename(columns=rename_dict)

# %% [markdown]
# # Get Fama-Bliss Discount (Zero-Coupon) Bonds

# %%
data_famabliss = db.get_table(library='crsp_m_treasuries', table='tfz_mth_fb').pivot_table(index='mcaldt',values='tmnomprc', columns='kytreasnox')
tag_famabliss_file = data_famabliss.index[-1].strftime('%Y-%m-%d')
data_famabliss.columns = [1,2,3,4,5]
data_famabliss.index.name = 'date'
data_famabliss.index = data_famabliss.index.astype('datetime64[ns]')
data_famabliss.index
data_famabliss /= 100

data_famabliss
# Out:
#                    1         2         3         4         5
# date
# 1952-06-30  0.981778  0.962531  0.942467  0.926341  0.904183
# 1952-07-31  0.980948  0.960315  0.939312  0.923089  0.898516
# 1952-08-29  0.980578  0.959750  0.937819  0.921458  0.895717
# 1952-09-30  0.980312  0.959098  0.937551  0.920961  0.891676
# 1952-10-31  0.981108  0.959745  0.937583  0.919290  0.897248
# ...              ...       ...       ...       ...       ...
# 2022-08-31  0.965955  0.933432  0.900600  0.871263  0.846584
# 2022-09-30  0.959839  0.918517  0.880655  0.846696  0.816731
# 2022-10-31  0.954288  0.914926  0.876564  0.841926  0.811304
# 2022-11-30  0.954375  0.918220  0.887608  0.857356  0.830593
# 2022-12-30  0.954636  0.916229  0.883347  0.851046  0.820298
#
# [847 rows x 5 columns]

# %% [markdown]
# # Save to Excel

# %%
outfile = f'../data/treasury_quotes_{DATE}.xlsx'
with pd.ExcelWriter(outfile) as writer:  
    data.to_excel(writer, sheet_name= 'quotes', index=False)

# %%
outfile = f'../data/treasury_ts_{MATDT}.xlsx'
with pd.ExcelWriter(outfile) as writer:  
    ts_info.T.to_excel(writer, sheet_name= 'info', index=True)
    ts.to_excel(writer, sheet_name= 'database', index=False)

# %%
outfile = f'../data/treasury_ts_issue_{KEYNO_ts}.xlsx'
with pd.ExcelWriter(outfile) as writer:  
    ts_issue.to_excel(writer, sheet_name= 'ts', index=False)

# %%
outfile = f'../data/treasury_ts_issue_TIPS_{KEYNO_tips}.xlsx'
with pd.ExcelWriter(outfile) as writer:  
    ts_issue_tips.to_excel(writer, sheet_name= 'ts', index=False)

# %%
outfile = f'../data/yields_{tag_yield_file}.xlsx'
with pd.ExcelWriter(outfile) as writer:
    data_ft.to_excel(writer, sheet_name= 'yields', index=True)

# %%
outfile = f'../data/treasury_ts_issue_duration_{KEYNO_ts_duration}.xlsx'
with pd.ExcelWriter(outfile) as writer:  
    info_ts_duration.to_excel(writer, sheet_name= 'info', index=True)
    ts_issue_duration.to_excel(writer, sheet_name= 'ts', index=False)

# %%
outfile = f'../data/treasury_zero_coupon_{tag_famabliss_file}.xlsx'
with pd.ExcelWriter(outfile) as writer:  
    data_famabliss.to_excel(writer, sheet_name= 'prices', index=True)
